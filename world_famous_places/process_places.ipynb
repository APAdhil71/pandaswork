# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\adhil\\OneDrive\\Desktop\\pandasworks\\world_famous_places\\world_famous_places_2024.csv")

# %%
df.head(3)
# Out:
#       Place_Name        Country           City  Annual_Visitors_Millions  \
# 0   Eiffel Tower         France          Paris                       7.0
# 1   Times Square  United States  New York City                      50.0
# 2  Louvre Museum         France          Paris                       8.7
#
#              Type UNESCO_World_Heritage Year_Built  Entry_Fee_USD  \
# 0  Monument/Tower                    No       1889             35
# 1  Urban Landmark                    No       1904              0
# 2          Museum                   Yes       1793             22
#
#     Best_Visit_Month          Region  Tourism_Revenue_Million_USD  \
# 0  May-June/Sept-Oct  Western Europe                           95
# 1  Apr-June/Sept-Nov   North America                           70
# 2          Oct-March  Western Europe                          120
#
#    Average_Visit_Duration_Hours  \
# 0                           2.5
# 1                           1.5
# 2                           4.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Place_Name                      0
# Country                         0
# City                            0
# Annual_Visitors_Millions        0
# Type                            0
# UNESCO_World_Heritage           0
# Year_Built                      0
# Entry_Fee_USD                   0
# Best_Visit_Month                0
# Region                          0
# Tourism_Revenue_Million_USD     0
# Average_Visit_Duration_Hours    0
# Famous_For                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Place_Name', 'Country', 'City', 'Annual_Visitors_Millions', 'Type',
#        'UNESCO_World_Heritage', 'Year_Built', 'Entry_Fee_USD',
#        'Best_Visit_Month', 'Region', 'Tourism_Revenue_Million_USD',
#        'Average_Visit_Duration_Hours', 'Famous_For'],
#       dtype='object')

# %%
#  Top 5 most visited places
df.sort_values(by="Annual_Visitors_Millions", ascending=False).head(5).sort_index()
# Out:
#                  Place_Name        Country           City  \
# 1              Times Square  United States  New York City
# 12             Central Park  United States  New York City
# 13          Las Vegas Strip  United States      Las Vegas
# 18  Disneyland (California)  United States        Anaheim
# 19  Magic Kingdom (Orlando)  United States        Orlando
#
#     Annual_Visitors_Millions                    Type UNESCO_World_Heritage  \
# 1                       50.0          Urban Landmark                    No
# 12                      42.0                    Park                    No
# 13                      41.7  Entertainment District                    No
# 18                      16.0              Theme Park                    No
# 19                      17.0              Theme Park                    No
#
#    Year_Built  Entry_Fee_USD    Best_Visit_Month         Region  \
# 1        1904              0   Apr-June/Sept-Nov  North America
# ...

# %%
# Which region has the most visitors
df.groupby("Region")["Annual_Visitors_Millions"].sum()
# Out:
# Region
# East Asia           19.00
# Middle East          6.00
# North Africa         2.80
# North America      205.10
# Oceania              8.20
# South America        3.70
# South Asia           7.50
# Southeast Asia       2.60
# Southern Europe     21.35
# Western Europe      63.70
# Name: Annual_Visitors_Millions, dtype: float64

# %%
# highest tourist revenue
df.sort_values(by="Tourism_Revenue_Million_USD", ascending=False).head()
# Out:
#                  Place_Name               Country       City  \
# 13          Las Vegas Strip         United States  Las Vegas
# 19  Magic Kingdom (Orlando)         United States    Orlando
# 18  Disneyland (California)         United States    Anaheim
# 20             Grand Canyon         United States    Arizona
# 25             Burj Khalifa  United Arab Emirates      Dubai
#
#     Annual_Visitors_Millions                    Type UNESCO_World_Heritage  \
# 13                      41.7  Entertainment District                    No
# 19                      17.0              Theme Park                    No
# 18                      16.0              Theme Park                    No
# 20                       6.0          Natural Wonder                   Yes
# 25                       6.0              Skyscraper                    No
#
#            Year_Built  Entry_Fee_USD    Best_Visit_Month         Region  \
# ...
